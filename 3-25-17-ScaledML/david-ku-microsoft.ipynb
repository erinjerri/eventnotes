# %% [markdown]
# ## David Ku (Microsoft) Scaled Machine Learning at Microsoft
#
# ## AI at Microsoft
# * Scaling Deep Learning
# * Learning from 2 scenarios
# * Driving prog in DL
# * Challenges + solutions
#
# ### ML integral part of products
# * Bing + ads - push limit of scale and agility
# * Kinect and Holoens - new UI metaphors
# * Cortana and Xioice - humant to cmoputer
# * office 365 - + linkedin - knowledge graphs
#
# ### Microsoft research has and continues to be active in ML AI research
# * Speech, vision, gesture, input
# * NLP, and convo dialogues
# * machine reading comp
# * systems for AI, AI for systems
# * as company has reached inflection point around AI
#
# * Be great in Inteliggent Agents + Assistants
#     * cortana, xiao, bots, virt customer assistants
#     * NL, diaglgo memory + context, tasks and domains
#
# * Strength AI capabilities and tech foundation
#     * data, telemetry, experiemtnation, modeling, devleop tools,
#     * strengthen AI tools + infra for 1st and 3rd party
#
# * Actively Infuse AI into Microsof tproducts
#     * Office, dynamics, Azure intelligence
#     * Delivering AI solutiosn and capabilities for our customers
#
# * Establish new org to drive this: AI + research

# %% [markdown]
# ### Bing
# * Deep Q&A
# * Every doc in web corpus, eahc ahving 30+ passages
# * Encoding of questions and passages, joint modeling and training, RL (reinforcement learning)
# * Critical: latency < 5-10ms
#
# ### Office
# * machine reading comp
# * massive: 18T emails, 250B updates 5+ PB logs daily
# * Representation of knowldge across neural and symoblic domains w/ doomain etensinos
# * Critical: strict data use compliance
#
# ### Infogrphic
# * Classical ML
# * Representation DL
# * Reinforcement DL
# * across categories: objective, learnign, features, label, data
#
# ### Infographic : Office + Substrate Intelligence
# generic compute, big data comput, ML capabiltiies

# %% [markdown]
# ### Scaling Deep L
#
# 5 ing for deep learning
# * data, lots of data
# * flexible models
# * enough computing power
# * computationally efficient inferences
#
# ### 5 challenges for dl
# * data policy and compliance
# agility to experiment
# cost-effecitve computing
# low-latency runtime
# vibran comm for collaboration and research
#
# ### citation: * priors that defeat curse of dimensionarlity
# Yosuhau Bengio talk 2017

# %% [markdown]
# ## Data policy and compliance
#
# ### Challenge
#
# Office 365 makes strong promise to users and biz customers
#
# * Country privacy laws
# * Contractual commitments
# * Microsoft privacy policy
#
# No eyes on access to content w/o explicit consnet
#
# // DoD and security
#
# Implication:
# * Limited data access for human inspectiona dn annotation
# * Data processing must stay within compliance boundary
# * Models need to be compalint, cannot reval data bw users and tenants
# * Infrastructure must respect country data sovereignty
#
# ### Solutions:
# Data access thru public datasets, employee/user donation programs, or approved anonymization straegies
#
# Compliant foundaiton, wher we apply strict engineering standsards for bldg compliant software and services, leeraging )365 infrastrucure servics
#
# Semi-supervised model to augment and scale training
#
# ### Actively exploring
# * Design user experience that elicit and encourage feeback
# * Hierarchical modeling of cross-tentna knowledge and patterns
# * New approaches to privacy differential or stochastic privacy
# * Unsupervised model training
#
# ## Agility to Experiment
# Challenge:
# * Model development often requiress work w/ models and algorithmss that are created on different DL frameworks
# * Lots of work to manage E2E agility, including model dev, offline experiematnion, onling flighting, and collab/sharing across groups
# * Significant time lag bw small early pilots to production-ready deployments
#
# Implication
# * Must support multiple DL frameworks w/ toosl to ease interoperability across them
# * Must support full lifecycle of ML model dev to deployment
# * Must ensure there is automated path to evolve from small pilots ato large scale production runs

# %% [markdown]
# ## Agility to Experiment Solutions
#
# * DL training cluster suport CNTK and TF models on GPUs, enable agility to explore and extend
# * DL inference as a service to automate and streamline deep model runtime
# * OpenMind extende Vis Stuiod and VS Code to support DL frameworks and Git to accelrate inner loop
#
# ### Actively exploring
# * Model and dataset seharing for ML collaboration, full lifecycle
# * Continue to embrace and integrate open source community of tools, code, and models into our environments
# * Improve debugging, visualization, and exploration of DL models
#
# ## OpenMind Studio
# *IDE for DL, supprots Mutliple DL frameworks and plat
#
# * Rich editing, debugign, intellisense and seymbolic exec
# * Local execution and alsysi, inegrate w/ tensoboard
# * Cloud deployment against multple fabrix and computing backends
# * CShared gallery on git fofr better collab, reuse, and sharing
#
# ### Cost-effective Computing
# Challenge
# * DL model trainign is exp and time-consuming, and there is never enough computing reserouces
# * Software and hardware acceleration
# GPU, FPGA, ASIC is necessary but complciated to do at scale
# Cost management is necessaryadn hard
#
# Implication
# * We must dramatically 10x-100x improve the perf/cost of compute to support DL
# * We must hide the complexity of hardware acceleration from the model devs
# * We should enable easy tradeoff bw perf and costs
#
# ML cloud infra to dyanmically optimzie across heterogensou compute resoruces
# New AI stack that enagbles ML/DL
#
# ##New AI Stack infographic
#
# * Top: Dev Exp: the vis studio fro ML/DL - data, model, algorithms, pipelline, experience, life cycle management
# * Programming Abstractiosn fro ML
#     * CNTK , DL Frameworks (TF), Open Source Data ML Frameworks (Spark, Hadoop)
# * Federated Infra Layer - Data Storage, compliance, Resourcmene Manage
# * Heterogenous Computing
#
# ### Low-latency runtime
# ### Solutions
# ### FPGA for DNN
# * FPGA configured in a hadawrad as a service (HaaS0 poo. w/ automated compiler to map CNTK/TF spec automatically to FPGA deployment over haaS
# * Azure info service to enable FGPA
# * DNN Inference acceleration
# * See infographics
#
# Solutions:
# * Emb cont to OSS : spark, YARN, HDFS, Dockers, HDX1 Open mind
#
# CNTF
# Datasets: MSMARC
